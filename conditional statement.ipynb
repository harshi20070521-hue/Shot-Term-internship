# %%
# this is if statement only
age = 18
if age >= 18:
    print("Eligible to vote")
# Out:
# Eligible to vote

# %%
# this is if-else statement only
num=int(input("Enter a number:"))  # for even number scenario
print(num)
print(type(num))
if num % 2 != 0:
  print("odd numbers")
else:
  print("even numbers")
# Out:
# Enter a number: 64
# 64
# <class 'int'>
# even numbers

# %%
# this is if-else statement only
num=int(input("Enter a number:")) #for odd numbers scenario 
print(num)
print(type(num))
if num % 2 != 0:
  print("odd numbers")
else:
  print("even numbers")
# Out:
# Enter a number: 359
# 359
# <class 'int'>
# odd numbers

# %%
# this is if-else statement only
age=int(input("Enter your age:")) # taken input as age less than 18
if age>18:
  print("Eligible for voting")
  print("you can also apply driving license")
else:
  print("Not eligible for voting")
# Out:
# Enter your age: 15
# Not eligible for voting

# %%
# this is if-else statement only
age=int(input("Enter your age:")) # taken input as age greater then 18
if age>18:
  print("Eligible for voting")
  print("you can also apply driving license")
else:
  print("Not eligible for voting")
# Out:
# Enter your age: 22
# Eligible for voting
# you can also apply driving license

# %%
# this is for elif statement only
marks =int(input("Enter your marks:")) 
print(marks)
print(type(marks))
if marks >= 90:
    print("Grade A")
elif marks >= 60:
    print("Grade B")
else:
    print("Grade C")
# Out:
# Enter your marks: 73
# 73
# <class 'int'>
# Grade B

# %%
# for nested if-else
num = int(input("Enter a number: ")) # when the number is neagtive
if num > 0:
    print("The number is positive")
    if num % 2 == 0:
        print("The number is even")
    else:
        print("The number is odd")
else:
    print("The number is not positive")
# Out:
# Enter a number:  -5489
# The number is not positive

# %%
# for nested if-else
num = int(input("Enter a number: ")) # when the number is positive
if num > 0:
    print("The number is positive")
    if num % 2 == 0:
        print("The number is even")
    else:
        print("The number is odd")
else:
    print("The number is not positive")
# Out:
# Enter a number:  6514
# The number is positive
# The number is even
